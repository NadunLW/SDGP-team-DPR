# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\dulsaradidul\opencv\lib\site-packages (0.9.0.1)
# Requirement already satisfied: opencv-python in c:\users\dulsaradidul\opencv\lib\site-packages (4.7.0.68)
# Requirement already satisfied: opencv-contrib-python in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (4.7.0.68)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (3.19.6)
# Requirement already satisfied: absl-py in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: numpy in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (1.21.6)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (23.1.21)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (22.2.0)
# Requirement already satisfied: matplotlib in c:\users\dulsaradidul\opencv\lib\site-packages (from mediapipe) (3.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dulsaradidul\opencv\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: typing-extensions in c:\users\dulsaradidul\opencv\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->mediapipe) (4.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\dulsaradidul\opencv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import mediapipe as mp
import numpy as np
import os
mpDraw = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
points = mp_pose.PoseLandmark # Landmarks
path1 = "dataset/good/1" # enter dataset path
path2 = "dataset/good/2"
data = []
data1 = []
data2 = []
for p in points:
        x = str(p)[13:]
        data1.append(x + "_x")
        data1.append(x + "_y")
        data1.append(x + "_z")
        data1.append(x + "_vis")
for p in points:
        x = str(p)[13:]
        data2.append(x + "_x")
        data2.append(x + "_y")
        data2.append(x + "_z")
        data2.append(x + "_vis")

# %%
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %%
count = 0

for img in os.listdir(path1):
    
            img = cv2.imread(path1 + "/" + img)

            imageWidth, imageHeight = img.shape[:2]

            imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            blackie = np.zeros(img.shape) # Blank image

            results = pose.process(imgRGB)
        
            # Extract landmarks
            try:
                landmarks = results.pose_landmarks.landmark

                # Get coordinates
                left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]

                # Calculate angle
                angle1 = calculate_angle(right_shoulder,right_hip,left_hip)

                # Visualize angle
                cv2.putText(img, str(angle1), 
                               tuple(np.multiply(right_hip, [640, 480]).astype(int)), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                                    )

                data1[count] = angle1

                count +=1
            
            except:
                pass

            cv2.imshow("Image", img)

            cv2.imshow("blackie",blackie)

            cv2.waitKey(100)

count = 0
            
for img in os.listdir(path2):
    
            img = cv2.imread(path2 + "/" + img)

            imageWidth, imageHeight = img.shape[:2]

            imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            blackie = np.zeros(img.shape) # Blank image

            results = pose.process(imgRGB)
        
            # Extract landmarks
            try:
                landmarks = results.pose_landmarks.landmark

                # Get coordinates
                left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]

                # Calculate angle
                angle1 = calculate_angle(right_shoulder,right_hip,left_hip)

                # Visualize angle
                cv2.putText(img, str(angle1), 
                               tuple(np.multiply(right_hip, [640, 480]).astype(int)), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                                    )

                data2[count] = angle1

                count +=1
            
            except:
                pass

            cv2.imshow("Image", img)

            cv2.imshow("blackie",blackie)

            cv2.waitKey(100)

data = data1 + data2

np.savetxt('good-posture1l.txt', data) # save the data as a txt file
# Out:
# [41.296000402718064, 41.21344803097547, 50.87124842333424, 52.934205483493834, 49.33000976730365, 46.17108588055696, 45.170644569562164, 44.78978416029214, 46.095855626586115, 45.85242897875836, 46.227995965859826, 45.77986683954186, 33.477211593827334, 33.48817349319766, 33.31803365791206, 33.39087637262488, 35.78426479662773, 35.46640540274791, 34.76629362237127, 36.72851418357485, 39.276450034744215, 41.98128843665223, 43.06803353556468, 39.01845377864183, 37.18185381470124, 37.87512680702191, 37.77139796894602, 41.36666183047724, 43.83897968287215, 43.289102257505206, 41.97164639092007, 40.62613461237742, 36.73892031042738, 36.58367407674865, 36.09088217347932, 35.88591761334795, 36.37551629703497, 36.25228673359119, 36.4958063172592, 36.5990173316153, 36.56634349681357, 36.721407645316155, 36.341803987385745, 36.00656598729776, 36.110856717597265, 36.802175058521165, 37.29300410651008, 37.20778806203871, 37.631065893536075, 36.34751414591265, 36.80554567699038, 37.16269131930646, 36.89824794958023, 35.71821059410666, 35.35152770834774, 34.394930747883805, 32.91978653274434, 33.704485050679814, 33.35739347079106, 32.973152789434785, 32.54752227784703, 31.151760281500003, 30.882245245750962, 30.24858652941008, 31.707179847585397, 33.51048857073173, 34.3777413806713, 34.34679539435383, 40.07290392936511, 50.07474344974898, 48.46061372585641, 41.692052052521795, 38.66598988284365, 36.993498471621876, 35.32993018667447, 33.33602953318179, 33.64851889132554, 33.01593005360182, 32.167716252305446, 32.481910771817965, 32.41011930330735, 32.34449847441814, 32.923731407753316, 33.052970352371396, 28.785912549042408, 28.123472168799246, 28.311241718072463, 27.38706922500001, 26.059033150936923, 25.585618349044655, 26.794540379217306, 38.039357842483994, 40.54747945338897, 45.16901065271869, 45.55602320556466, 48.399552375009634, 44.88212969576388, 44.46313245805196, 46.461873237132274, 46.05833383908284, 37.39147379759549, 37.713234706451196, 39.50591578819644, 39.661661947274546, 39.64265220775659, 39.24410518304915, 37.034238435617866, 30.809189790217186, 29.865743653657304, 31.072410147109895, 29.707753613264178, 31.650097140645062, 31.349442247469, 31.13428416488375, 31.712124149575367, 31.226625787954237, 30.40670556740298, 29.842073240345563, 29.101352988110378, 28.849286351769372, 28.383820000252545, 29.06869085252385, 28.182526051822435, 29.188879873982685, 29.828362380234104, 30.362843784029568, 32.445875723102674, 32.092601214770106, 32.17067474172866, 28.647419871706678, 28.47203631456711, 26.02673792167388]
