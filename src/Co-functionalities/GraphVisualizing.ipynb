# %%
import matplotlib.pyplot as plt
import numpy as np
series = []
file = open('../csv/graph.txt', 'r') #read the previous posture status to display the graph
while file.readline() != "":
    try:
        series.append(int(file.readline()))
    except:
        pass
file.close()
length = len(series) # calculate read status array list length for adjusting x axis
def graphVisualization(x, y):
    x_axis = np.array(range(x))
    y_axis = np.array(y)

    plt.plot(x_axis, y_axis)
    plt.title('Posture Analysis')
    plt.xlabel('seconds')
    plt.ylabel('status\n-2 - Poor, -1 - Bad, 0 - Average, 1 - Good, 2 - Excellent')
    return plt.show()
graphVisualization(length, series)
    
# !pip install pytest
import pytest
def test_graphVisualization():
    x = np.array(range(5))
    y = np.array([-2,-1,0,1,2])
    plt.plot(x, y)
    assert graphVisualization(x, y) == plt.show()
test_graphVisualization()
# Out:
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16196\350746335.py in <module>
#      28     plt.plot(x, y)
#      29     assert graphVisualization(x, y) == plt.show()
# ---> 30 test_graphVisualization()
#
# ~\AppData\Local\Temp\ipykernel_16196\350746335.py in test_graphVisualization()
#      27     y = np.array([-2,-1,0,1,2])
#      28     plt.plot(x, y)
# ---> 29     assert graphVisualization(x, y) == plt.show()
#      30 test_graphVisualization()
#
# ~\AppData\Local\Temp\ipykernel_16196\350746335.py in graphVisualization(x, y)
#      11 length = len(series) # calculate read status array list length for adjusting x axis
#      12 def graphVisualization(x, y):
# ---> 13     x_axis = np.array(range(x))
# ...
