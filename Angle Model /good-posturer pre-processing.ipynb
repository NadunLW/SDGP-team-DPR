# %%
import os, platform
print('OS name:', os.name, ', system:', platform.system(), ', release:', platform.release())
import sys
print("Anaconda version:")
# !conda list anaconda
print("Python version: ", sys.version)
print("Python version info: ", sys.version_info)
import PIL
print("PIL version: ", PIL.__version__)
import matplotlib
print("Matplotlib version: ", matplotlib.__version__)
import tensorflow as tf
from tensorflow import keras
print("Keras version:", tf.keras.__version__)
import cv2
print("OpenCV version: ", cv2.__version__)
# Out:
# OS name: nt , system: Windows , release: 10
# Anaconda version:
# # packages in environment at C:\Users\DulsaraDidul\anaconda3:
# #
# # Name                    Version                   Build  Channel
# anaconda                  2022.10                  py39_0
# anaconda-client           1.11.0           py39haa95532_0
# anaconda-navigator        2.3.1            py39haa95532_0
# anaconda-project          0.11.1           py39haa95532_0
# Python version:  3.7.4 (tags/v3.7.4:e09359112e, Jul  8 2019, 20:34:20) [MSC v.1916 64 bit (AMD64)]
# Python version info:  sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)
# PIL version:  9.4.0
# Matplotlib version:  3.5.3
# Keras version: 2.11.0
# OpenCV version:  4.7.0

# %%
# A. IMAGE MANIPULATION with PIL - Python Image Library
# First of all, VIEWing an IMAGE
# - first import necessary libraries
import numpy as np
from PIL import Image
# - set a few generic variables
FilePath = 'dataset/good/1/'
FileExt = '.jpg'
for FileName in range(145):
    ImageFile = FilePath + str(FileName) + FileExt
    # - open the imagefile
    img = Image.open(ImageFile)
    # - inspect necessary information
    print('Image format: ', img.format)
    print('Image mode: ', img.mode)
    # - display
    img.show()
    # A.1. CONVERT an IMAGE to NP ARRAY
    # - first import necessary libraries
    from numpy import asarray
    # - convert image format to numpy array
    data = asarray(img)
    # - inspect necessary information
    print('data type: ', type(data))
    print('data shape: ', data.shape)
    print(data)
    # A.2. CONVERT NP ARRAY back to IMAGE format
    # - convert numpy array to image format
    img_fromnparray = Image.fromarray(data)
    img_fromnparray.show()
    # - inspect necessary information
    print('Image size: ', img_fromnparray.size)
    print('Image format: ', img_fromnparray.format)
    print('Image mode: ', img_fromnparray.mode)
    # A.3. SAVE the IMAGE to ANOTHER FORMAT, e.g. PNG (source was JPG before)
    #  - 1st reopen image, and save is as PNG
    data = asarray(Image.open(ImageFile))
    print("Saving as PNG (RGB)...", FilePath + str(FileName))
    print(type(data), data.shape)
    img_png = Image.fromarray(data).save(FilePath + str(FileName) + '_pil-rgb' + '.png')
    #  - 2nd reopen image and convert it to grey, and save is as PNG
    data = asarray(Image.open(ImageFile).convert('L'))
    print("Saving as PNG (Grey)...", FilePath + str(FileName))
    print(type(data), data.shape)
    img_png = Image.fromarray(data).save(FilePath + str(FileName) + '_pil-grey' + '.png')
    # B. IMAGE MANIPULATION with Matplotlib
    # - first import necessary libraries
    from matplotlib import image, pyplot
    img = image.imread(ImageFile)
    # - inspect necessary information
    print('Image dtype: ', img.dtype)
    print('Image shape: ', img.shape)
    # - then show the image
    pyplot.imshow(img)
    # pyplot.show()
    #  - Image Enhancements with PIL: Contrast
    from PIL import ImageEnhance
    im = Image.open(ImageFile)
    enh = ImageEnhance.Contrast(im)
    enh.enhance(1.75).show("75% more contrast")
    #  - Image Enhancements with PIL: Brightness
    enh = ImageEnhance.Brightness(im)
    enh.enhance(1.5).show("50% more brightness")
    # C. IMAGE MANIPULATION with Keras (built on top of Tensorflow)
    # - first import necessary libraries
    from tensorflow.keras.utils import load_img
    import warnings
    # - load and view the image
    img = load_img(ImageFile)
    print('Image type:', type(img), ', image format:', img.format, ', image mode:', img.mode, ', image size:', img.size)
    img.show()
    from tensorflow.keras.utils import img_to_array, array_to_img
    print('Original type of image:', type(img))
    # - convert the image to numpy array
    img_nparray = img_to_array(img)
    print('Numpy array info:', type(img_nparray))
    print('type:', type(img_nparray.dtype))
    print('shape:', type(img_nparray.shape))
    from tensorflow.keras.utils import img_to_array, array_to_img
    print('Original type of image:', type(img))
    # - convert the image to numpy array
    img_nparray = img_to_array(img)
    print('Numpy array info:', type(img_nparray))
    print('type:', type(img_nparray.dtype))
    print('shape:', type(img_nparray.shape))
    from tensorflow.keras.utils import img_to_array, array_to_img
    print('Original type of image:', type(img))
    # - convert the image to numpy array
    img_nparray = img_to_array(img)
    print('Numpy array info:', type(img_nparray))
    print('type:', type(img_nparray.dtype))
    print('shape:', type(img_nparray.shape))
    print(img_nparray)
    img_pil = array_to_img(img_nparray)
    print("Converted (back) type of the image:", type(img_pil))
    # - saving an image with keras
    from tensorflow.keras.utils import load_img, save_img
    ImageFile = FilePath + str(FileName) + '_keras' + '.png'
    print("Saving Image File with Keras...", FilePath + str(FileName))
    save_img(ImageFile, img_nparray)
    # - loading an image with keras
    print("Loading Image File with Keras...", FilePath + str(FileName))
    img = load_img(ImageFile)
    print('Image type:', type(img), ', image format:', img.format, ', image mode:', img.mode, ', image size:', img.size)
    img.show()
    # *********************************
    # D. IMAGE MANIPULATION with OpenCV
    # *********************************
    # - first import necessary libraries
    # import cv2
    # - set ImageFile to our original image, then read the image
    ImageFile = FilePath + str(FileName) + FileExt
    im = cv2.imread(ImageFile)
    #cv2.imshow("my image", im)
    # - save the file as PNG before conversion (internally it's in BGR order)
    cv2.imwrite(FilePath + str(FileName) + '_opencvRGB' + '.png', im)
    print(type(img))
    # - convert to GRAY color space
    img = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    # - save the file as PNG after conversion
    cv2.imwrite(FilePath + str(FileName) + '_opencvGREY' + '.png', img)
    # - convert to HSV color space (typical for object tracking)
    img = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
    # - save the file as PNG after conversion
    cv2.imwrite(FilePath + str(FileName) + '_opencvHSV' + '.png', img)
    # - apply 50% blur
    #   alternatively we can use cv2.imshow() to display the image instead of writing it to a file
    #   e.g.:
    #     cv2.imshow("OpenCV: apply 50% blur", img)
    #     cv2.waitKey(0)
    img = cv2.medianBlur(im, 5)
    cv2.imwrite(FilePath + str(FileName) + '_opencvBLUR' + '.png', img)
    # - apply Edge Detection
    img = cv2.Canny(im, 100, 200)
    cv2.imwrite(FilePath + str(FileName) + '_opencvEdgeDetect' + '.png', img)
# Out:
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0 14  0]
#   [ 0 12  0]
#   [ 0 11  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 1 15  0]
#   [ 1 13  1]
#   [ 0 12  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 1 15  0]
#   [ 1 13  1]
#   [ 0 12  0]]
#
#  ...
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/0
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/0
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0. 14.  0.]
#   [ 0. 12.  0.]
#   [ 0. 11.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 1. 15.  0.]
#   [ 1. 13.  1.]
#   [ 0. 12.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 1. 15.  0.]
#   [ 1. 13.  1.]
#   [ 0. 12.  0.]]
#
#  ...
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/0
# Loading Image File with Keras... dataset/good/1/0
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 53  31  44]
#   [ 51  29  41]
#   [ 51  27  40]
#   ...
#   [154 139 136]
#   [155 141 138]
#   [159 145 142]]
#
#  [[ 51  29  42]
#   [ 50  28  40]
#   [ 51  29  41]
#   ...
#   [156 141 138]
#   [155 140 137]
#   [156 141 138]]
#
#  [[ 51  31  43]
#   [ 51  31  42]
#   [ 51  31  42]
#   ...
#   [158 140 140]
#   [158 140 140]
#   [158 140 140]]
#
#  ...
#
#  [[ 51  32  38]
#   [ 52  33  39]
#   [ 51  31  40]
#   ...
#   [ 38  22  33]
#   [ 39  21  33]
#   [ 39  22  32]]
#
#  [[ 49  32  38]
#   [ 48  31  37]
#   [ 49  29  38]
#   ...
#   [ 39  21  33]
#   [ 39  21  33]
#   [ 39  21  33]]
#
#  [[ 49  32  38]
#   [ 47  30  36]
#   [ 48  28  37]
#   ...
#   [ 40  22  36]
#   [ 40  22  34]
#   [ 40  22  34]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/1
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/1
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 53.  31.  44.]
#   [ 51.  29.  41.]
#   [ 51.  27.  40.]
#   ...
#   [154. 139. 136.]
#   [155. 141. 138.]
#   [159. 145. 142.]]
#
#  [[ 51.  29.  42.]
#   [ 50.  28.  40.]
#   [ 51.  29.  41.]
#   ...
#   [156. 141. 138.]
#   [155. 140. 137.]
#   [156. 141. 138.]]
#
#  [[ 51.  31.  43.]
#   [ 51.  31.  42.]
#   [ 51.  31.  42.]
#   ...
#   [158. 140. 140.]
#   [158. 140. 140.]
#   [158. 140. 140.]]
#
#  ...
#
#  [[ 51.  32.  38.]
#   [ 52.  33.  39.]
#   [ 51.  31.  40.]
#   ...
#   [ 38.  22.  33.]
#   [ 39.  21.  33.]
#   [ 39.  22.  32.]]
#
#  [[ 49.  32.  38.]
#   [ 48.  31.  37.]
#   [ 49.  29.  38.]
#   ...
#   [ 39.  21.  33.]
#   [ 39.  21.  33.]
#   [ 39.  21.  33.]]
#
#  [[ 49.  32.  38.]
#   [ 47.  30.  36.]
#   [ 48.  28.  37.]
#   ...
#   [ 40.  22.  36.]
#   [ 40.  22.  34.]
#   [ 40.  22.  34.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/1
# Loading Image File with Keras... dataset/good/1/1
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 28  26  27]
#   [ 26  24  25]
#   [ 25  24  29]
#   ...
#   [130 140 139]
#   [127 138 134]
#   [131 142 138]]
#
#  [[ 27  25  26]
#   [ 26  24  27]
#   [ 27  25  28]
#   ...
#   [132 142 141]
#   [127 138 134]
#   [129 140 136]]
#
#  [[ 29  24  28]
#   [ 26  24  27]
#   [ 28  26  29]
#   ...
#   [133 143 142]
#   [127 139 137]
#   [129 141 139]]
#
#  ...
#
#  [[ 29  28  24]
#   [ 27  26  22]
#   [ 26  25  21]
#   ...
#   [ 22  21  27]
#   [ 22  21  26]
#   [ 22  22  24]]
#
#  [[ 28  27  22]
#   [ 26  25  20]
#   [ 25  26  20]
#   ...
#   [ 20  21  25]
#   [ 21  22  24]
#   [ 21  23  22]]
#
#  [[ 28  27  22]
#   [ 25  24  19]
#   [ 24  25  19]
#   ...
#   [ 21  22  26]
#   [ 21  22  24]
#   [ 20  22  21]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/2
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/2
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 28.  26.  27.]
#   [ 26.  24.  25.]
#   [ 25.  24.  29.]
#   ...
#   [130. 140. 139.]
#   [127. 138. 134.]
#   [131. 142. 138.]]
#
#  [[ 27.  25.  26.]
#   [ 26.  24.  27.]
#   [ 27.  25.  28.]
#   ...
#   [132. 142. 141.]
#   [127. 138. 134.]
#   [129. 140. 136.]]
#
#  [[ 29.  24.  28.]
#   [ 26.  24.  27.]
#   [ 28.  26.  29.]
#   ...
#   [133. 143. 142.]
#   [127. 139. 137.]
#   [129. 141. 139.]]
#
#  ...
#
#  [[ 29.  28.  24.]
#   [ 27.  26.  22.]
#   [ 26.  25.  21.]
#   ...
#   [ 22.  21.  27.]
#   [ 22.  21.  26.]
#   [ 22.  22.  24.]]
#
#  [[ 28.  27.  22.]
#   [ 26.  25.  20.]
#   [ 25.  26.  20.]
#   ...
#   [ 20.  21.  25.]
#   [ 21.  22.  24.]
#   [ 21.  23.  22.]]
#
#  [[ 28.  27.  22.]
#   [ 25.  24.  19.]
#   [ 24.  25.  19.]
#   ...
#   [ 21.  22.  26.]
#   [ 21.  22.  24.]
#   [ 20.  22.  21.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/2
# Loading Image File with Keras... dataset/good/1/2
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 24  22  33]
#   [ 26  24  35]
#   [ 26  25  33]
#   ...
#   [129 132 139]
#   [129 132 139]
#   [124 127 134]]
#
#  [[ 28  26  37]
#   [ 26  24  35]
#   [ 25  24  32]
#   ...
#   [130 133 138]
#   [132 135 142]
#   [131 134 139]]
#
#  [[ 28  26  37]
#   [ 25  23  34]
#   [ 25  24  32]
#   ...
#   [135 136 140]
#   [137 138 143]
#   [135 136 140]]
#
#  ...
#
#  [[ 33  26  33]
#   [ 31  26  30]
#   [ 29  27  28]
#   ...
#   [ 22  20  23]
#   [ 23  21  24]
#   [ 23  21  24]]
#
#  [[ 32  27  34]
#   [ 29  27  32]
#   [ 30  28  31]
#   ...
#   [ 24  19  23]
#   [ 24  19  23]
#   [ 24  19  23]]
#
#  [[ 31  28  37]
#   [ 30  27  34]
#   [ 30  28  31]
#   ...
#   [ 23  18  22]
#   [ 24  18  22]
#   [ 23  17  21]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/3
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/3
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 24.  22.  33.]
#   [ 26.  24.  35.]
#   [ 26.  25.  33.]
#   ...
#   [129. 132. 139.]
#   [129. 132. 139.]
#   [124. 127. 134.]]
#
#  [[ 28.  26.  37.]
#   [ 26.  24.  35.]
#   [ 25.  24.  32.]
#   ...
#   [130. 133. 138.]
#   [132. 135. 142.]
#   [131. 134. 139.]]
#
#  [[ 28.  26.  37.]
#   [ 25.  23.  34.]
#   [ 25.  24.  32.]
#   ...
#   [135. 136. 140.]
#   [137. 138. 143.]
#   [135. 136. 140.]]
#
#  ...
#
#  [[ 33.  26.  33.]
#   [ 31.  26.  30.]
#   [ 29.  27.  28.]
#   ...
#   [ 22.  20.  23.]
#   [ 23.  21.  24.]
#   [ 23.  21.  24.]]
#
#  [[ 32.  27.  34.]
#   [ 29.  27.  32.]
#   [ 30.  28.  31.]
#   ...
#   [ 24.  19.  23.]
#   [ 24.  19.  23.]
#   [ 24.  19.  23.]]
#
#  [[ 31.  28.  37.]
#   [ 30.  27.  34.]
#   [ 30.  28.  31.]
#   ...
#   [ 23.  18.  22.]
#   [ 24.  18.  22.]
#   [ 23.  17.  21.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/3
# Loading Image File with Keras... dataset/good/1/3
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 29  22  29]
#   [ 32  26  30]
#   [ 29  24  28]
#   ...
#   [139 142 131]
#   [140 141 133]
#   [139 140 132]]
#
#  [[ 25  18  25]
#   [ 26  20  24]
#   [ 29  25  26]
#   ...
#   [138 141 130]
#   [139 141 130]
#   [135 137 126]]
#
#  [[ 30  24  28]
#   [ 28  22  26]
#   [ 31  27  28]
#   ...
#   [139 143 129]
#   [145 147 134]
#   [144 146 133]]
#
#  ...
#
#  [[ 32  28  27]
#   [ 28  27  25]
#   [ 29  28  26]
#   ...
#   [ 21  15  27]
#   [ 22  16  28]
#   [ 21  15  25]]
#
#  [[ 34  29  26]
#   [ 30  25  22]
#   [ 33  27  27]
#   ...
#   [ 23  17  29]
#   [ 21  18  29]
#   [ 20  17  28]]
#
#  [[ 37  29  27]
#   [ 31  23  21]
#   [ 33  27  27]
#   ...
#   [ 24  18  32]
#   [ 22  19  30]
#   [ 22  19  30]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/4
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/4
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 29.  22.  29.]
#   [ 32.  26.  30.]
#   [ 29.  24.  28.]
#   ...
#   [139. 142. 131.]
#   [140. 141. 133.]
#   [139. 140. 132.]]
#
#  [[ 25.  18.  25.]
#   [ 26.  20.  24.]
#   [ 29.  25.  26.]
#   ...
#   [138. 141. 130.]
#   [139. 141. 130.]
#   [135. 137. 126.]]
#
#  [[ 30.  24.  28.]
#   [ 28.  22.  26.]
#   [ 31.  27.  28.]
#   ...
#   [139. 143. 129.]
#   [145. 147. 134.]
#   [144. 146. 133.]]
#
#  ...
#
#  [[ 32.  28.  27.]
#   [ 28.  27.  25.]
#   [ 29.  28.  26.]
#   ...
#   [ 21.  15.  27.]
#   [ 22.  16.  28.]
#   [ 21.  15.  25.]]
#
#  [[ 34.  29.  26.]
#   [ 30.  25.  22.]
#   [ 33.  27.  27.]
#   ...
#   [ 23.  17.  29.]
#   [ 21.  18.  29.]
#   [ 20.  17.  28.]]
#
#  [[ 37.  29.  27.]
#   [ 31.  23.  21.]
#   [ 33.  27.  27.]
#   ...
#   [ 24.  18.  32.]
#   [ 22.  19.  30.]
#   [ 22.  19.  30.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/4
# Loading Image File with Keras... dataset/good/1/4
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 42  28  43]
#   [ 40  28  40]
#   [ 40  28  40]
#   ...
#   [161 162 148]
#   [161 161 149]
#   [164 164 152]]
#
#  [[ 38  24  37]
#   [ 35  23  35]
#   [ 34  24  33]
#   ...
#   [165 165 153]
#   [163 163 153]
#   [156 156 146]]
#
#  [[ 37  26  34]
#   [ 38  27  35]
#   [ 40  31  36]
#   ...
#   [161 162 154]
#   [161 162 156]
#   [161 162 156]]
#
#  ...
#
#  [[ 47  37  36]
#   [ 39  31  28]
#   [ 38  31  25]
#   ...
#   [ 30  27  18]
#   [ 29  27  15]
#   [ 30  28  15]]
#
#  [[ 42  34  31]
#   [ 37  30  24]
#   [ 35  31  22]
#   ...
#   [ 29  26  17]
#   [ 29  29  17]
#   [ 29  30  16]]
#
#  [[ 39  32  26]
#   [ 39  35  26]
#   [ 41  37  28]
#   ...
#   [ 28  25  16]
#   [ 31  31  19]
#   [ 29  30  16]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/5
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/5
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 42.  28.  43.]
#   [ 40.  28.  40.]
#   [ 40.  28.  40.]
#   ...
#   [161. 162. 148.]
#   [161. 161. 149.]
#   [164. 164. 152.]]
#
#  [[ 38.  24.  37.]
#   [ 35.  23.  35.]
#   [ 34.  24.  33.]
#   ...
#   [165. 165. 153.]
#   [163. 163. 153.]
#   [156. 156. 146.]]
#
#  [[ 37.  26.  34.]
#   [ 38.  27.  35.]
#   [ 40.  31.  36.]
#   ...
#   [161. 162. 154.]
#   [161. 162. 156.]
#   [161. 162. 156.]]
#
#  ...
#
#  [[ 47.  37.  36.]
#   [ 39.  31.  28.]
#   [ 38.  31.  25.]
#   ...
#   [ 30.  27.  18.]
#   [ 29.  27.  15.]
#   [ 30.  28.  15.]]
#
#  [[ 42.  34.  31.]
#   [ 37.  30.  24.]
#   [ 35.  31.  22.]
#   ...
#   [ 29.  26.  17.]
#   [ 29.  29.  17.]
#   [ 29.  30.  16.]]
#
#  [[ 39.  32.  26.]
#   [ 39.  35.  26.]
#   [ 41.  37.  28.]
#   ...
#   [ 28.  25.  16.]
#   [ 31.  31.  19.]
#   [ 29.  30.  16.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/5
# Loading Image File with Keras... dataset/good/1/5
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 44  35  40]
#   [ 39  30  35]
#   [ 38  29  34]
#   ...
#   [160 163 156]
#   [155 158 151]
#   [156 159 152]]
#
#  [[ 41  32  35]
#   [ 39  30  33]
#   [ 38  29  32]
#   ...
#   [158 161 154]
#   [158 161 154]
#   [157 160 151]]
#
#  [[ 41  31  32]
#   [ 41  31  32]
#   [ 40  30  31]
#   ...
#   [159 165 155]
#   [158 164 154]
#   [152 158 146]]
#
#  ...
#
#  [[ 36  41  34]
#   [ 34  39  32]
#   [ 34  37  30]
#   ...
#   [ 28  22  26]
#   [ 28  21  28]
#   [ 28  21  28]]
#
#  [[ 35  42  35]
#   [ 34  39  33]
#   [ 33  38  31]
#   ...
#   [ 27  22  26]
#   [ 28  22  26]
#   [ 29  23  27]]
#
#  [[ 32  39  32]
#   [ 32  39  32]
#   [ 34  39  32]
#   ...
#   [ 27  22  26]
#   [ 28  22  26]
#   [ 28  22  26]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/6
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/6
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 44.  35.  40.]
#   [ 39.  30.  35.]
#   [ 38.  29.  34.]
#   ...
#   [160. 163. 156.]
#   [155. 158. 151.]
#   [156. 159. 152.]]
#
#  [[ 41.  32.  35.]
#   [ 39.  30.  33.]
#   [ 38.  29.  32.]
#   ...
#   [158. 161. 154.]
#   [158. 161. 154.]
#   [157. 160. 151.]]
#
#  [[ 41.  31.  32.]
#   [ 41.  31.  32.]
#   [ 40.  30.  31.]
#   ...
#   [159. 165. 155.]
#   [158. 164. 154.]
#   [152. 158. 146.]]
#
#  ...
#
#  [[ 36.  41.  34.]
#   [ 34.  39.  32.]
#   [ 34.  37.  30.]
#   ...
#   [ 28.  22.  26.]
#   [ 28.  21.  28.]
#   [ 28.  21.  28.]]
#
#  [[ 35.  42.  35.]
#   [ 34.  39.  33.]
#   [ 33.  38.  31.]
#   ...
#   [ 27.  22.  26.]
#   [ 28.  22.  26.]
#   [ 29.  23.  27.]]
#
#  [[ 32.  39.  32.]
#   [ 32.  39.  32.]
#   [ 34.  39.  32.]
#   ...
#   [ 27.  22.  26.]
#   [ 28.  22.  26.]
#   [ 28.  22.  26.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/6
# Loading Image File with Keras... dataset/good/1/6
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 43  30  39]
#   [ 45  32  41]
#   [ 45  31  44]
#   ...
#   [172 170 173]
#   [167 165 166]
#   [170 168 169]]
#
#  [[ 39  26  35]
#   [ 46  33  42]
#   [ 47  34  44]
#   ...
#   [168 168 170]
#   [169 167 170]
#   [168 168 170]]
#
#  [[ 45  34  42]
#   [ 46  35  43]
#   [ 54  42  52]
#   ...
#   [165 166 170]
#   [172 171 176]
#   [166 167 171]]
#
#  ...
#
#  [[ 44  38  40]
#   [ 44  38  40]
#   [ 45  39  39]
#   ...
#   [ 33  33  25]
#   [ 33  32  27]
#   [ 28  29  21]]
#
#  [[ 50  38  38]
#   [ 47  37  36]
#   [ 46  38  35]
#   ...
#   [ 34  31  22]
#   [ 30  30  22]
#   [ 25  25  15]]
#
#  [[ 53  39  38]
#   [ 49  38  36]
#   [ 48  39  34]
#   ...
#   [ 31  28  19]
#   [ 33  30  21]
#   [ 31  31  21]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/7
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/7
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 43.  30.  39.]
#   [ 45.  32.  41.]
#   [ 45.  31.  44.]
#   ...
#   [172. 170. 173.]
#   [167. 165. 166.]
#   [170. 168. 169.]]
#
#  [[ 39.  26.  35.]
#   [ 46.  33.  42.]
#   [ 47.  34.  44.]
#   ...
#   [168. 168. 170.]
#   [169. 167. 170.]
#   [168. 168. 170.]]
#
#  [[ 45.  34.  42.]
#   [ 46.  35.  43.]
#   [ 54.  42.  52.]
#   ...
#   [165. 166. 170.]
#   [172. 171. 176.]
#   [166. 167. 171.]]
#
#  ...
#
#  [[ 44.  38.  40.]
#   [ 44.  38.  40.]
#   [ 45.  39.  39.]
#   ...
#   [ 33.  33.  25.]
#   [ 33.  32.  27.]
#   [ 28.  29.  21.]]
#
#  [[ 50.  38.  38.]
#   [ 47.  37.  36.]
#   [ 46.  38.  35.]
#   ...
#   [ 34.  31.  22.]
#   [ 30.  30.  22.]
#   [ 25.  25.  15.]]
#
#  [[ 53.  39.  38.]
#   [ 49.  38.  36.]
#   [ 48.  39.  34.]
#   ...
#   [ 31.  28.  19.]
#   [ 33.  30.  21.]
#   [ 31.  31.  21.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/7
# Loading Image File with Keras... dataset/good/1/7
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 43  41  42]
#   [ 46  44  45]
#   [ 51  46  50]
#   ...
#   [162 171 170]
#   [162 170 173]
#   [173 181 184]]
#
#  [[ 52  48  49]
#   [ 46  42  43]
#   [ 45  41  42]
#   ...
#   [167 176 173]
#   [170 179 178]
#   [167 175 177]]
#
#  [[ 45  39  39]
#   [ 45  39  39]
#   [ 45  39  41]
#   ...
#   [172 179 172]
#   [173 179 175]
#   [170 176 172]]
#
#  ...
#
#  [[ 38  33  37]
#   [ 39  35  36]
#   [ 44  40  41]
#   ...
#   [ 34  29  36]
#   [ 34  28  38]
#   [ 33  28  35]]
#
#  [[ 36  28  39]
#   [ 39  32  40]
#   [ 46  39  46]
#   ...
#   [ 36  29  36]
#   [ 34  27  35]
#   [ 31  24  31]]
#
#  [[ 38  30  45]
#   [ 38  30  43]
#   [ 41  34  42]
#   ...
#   [ 36  29  36]
#   [ 29  22  29]
#   [ 31  24  31]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/8
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/8
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 43.  41.  42.]
#   [ 46.  44.  45.]
#   [ 51.  46.  50.]
#   ...
#   [162. 171. 170.]
#   [162. 170. 173.]
#   [173. 181. 184.]]
#
#  [[ 52.  48.  49.]
#   [ 46.  42.  43.]
#   [ 45.  41.  42.]
#   ...
#   [167. 176. 173.]
#   [170. 179. 178.]
#   [167. 175. 177.]]
#
#  [[ 45.  39.  39.]
#   [ 45.  39.  39.]
#   [ 45.  39.  41.]
#   ...
#   [172. 179. 172.]
#   [173. 179. 175.]
#   [170. 176. 172.]]
#
#  ...
#
#  [[ 38.  33.  37.]
#   [ 39.  35.  36.]
#   [ 44.  40.  41.]
#   ...
#   [ 34.  29.  36.]
#   [ 34.  28.  38.]
#   [ 33.  28.  35.]]
#
#  [[ 36.  28.  39.]
#   [ 39.  32.  40.]
#   [ 46.  39.  46.]
#   ...
#   [ 36.  29.  36.]
#   [ 34.  27.  35.]
#   [ 31.  24.  31.]]
#
#  [[ 38.  30.  45.]
#   [ 38.  30.  43.]
#   [ 41.  34.  42.]
#   ...
#   [ 36.  29.  36.]
#   [ 29.  22.  29.]
#   [ 31.  24.  31.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/8
# Loading Image File with Keras... dataset/good/1/8
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 49  37  41]
#   [ 49  37  41]
#   [ 51  40  48]
#   ...
#   [167 165 168]
#   [172 169 176]
#   [171 168 175]]
#
#  [[ 52  39  46]
#   [ 49  38  44]
#   [ 52  41  49]
#   ...
#   [170 170 172]
#   [173 171 176]
#   [171 170 175]]
#
#  [[ 53  41  51]
#   [ 50  40  49]
#   [ 52  42  50]
#   ...
#   [173 175 174]
#   [174 174 174]
#   [171 172 174]]
#
#  ...
#
#  [[ 42  44  33]
#   [ 42  44  33]
#   [ 41  42  34]
#   ...
#   [ 33  27  27]
#   [ 33  27  29]
#   [ 34  28  30]]
#
#  [[ 43  47  32]
#   [ 42  46  31]
#   [ 38  42  28]
#   ...
#   [ 35  26  31]
#   [ 35  25  33]
#   [ 34  24  32]]
#
#  [[ 40  47  29]
#   [ 38  45  27]
#   [ 37  41  27]
#   ...
#   [ 34  24  32]
#   [ 35  25  34]
#   [ 34  24  33]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/9
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/9
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 49.  37.  41.]
#   [ 49.  37.  41.]
#   [ 51.  40.  48.]
#   ...
#   [167. 165. 168.]
#   [172. 169. 176.]
#   [171. 168. 175.]]
#
#  [[ 52.  39.  46.]
#   [ 49.  38.  44.]
#   [ 52.  41.  49.]
#   ...
#   [170. 170. 172.]
#   [173. 171. 176.]
#   [171. 170. 175.]]
#
#  [[ 53.  41.  51.]
#   [ 50.  40.  49.]
#   [ 52.  42.  50.]
#   ...
#   [173. 175. 174.]
#   [174. 174. 174.]
#   [171. 172. 174.]]
#
#  ...
#
#  [[ 42.  44.  33.]
#   [ 42.  44.  33.]
#   [ 41.  42.  34.]
#   ...
#   [ 33.  27.  27.]
#   [ 33.  27.  29.]
#   [ 34.  28.  30.]]
#
#  [[ 43.  47.  32.]
#   [ 42.  46.  31.]
#   [ 38.  42.  28.]
#   ...
#   [ 35.  26.  31.]
#   [ 35.  25.  33.]
#   [ 34.  24.  32.]]
#
#  [[ 40.  47.  29.]
#   [ 38.  45.  27.]
#   [ 37.  41.  27.]
#   ...
#   [ 34.  24.  32.]
#   [ 35.  25.  34.]
#   [ 34.  24.  33.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/9
# Loading Image File with Keras... dataset/good/1/9
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 48  36  38]
#   [ 50  38  40]
#   [ 56  46  45]
#   ...
#   [165 164 178]
#   [164 163 181]
#   [165 164 182]]
#
#  [[ 52  40  42]
#   [ 52  40  42]
#   [ 56  46  47]
#   ...
#   [164 164 176]
#   [161 160 174]
#   [161 160 176]]
#
#  [[ 53  41  45]
#   [ 53  41  45]
#   [ 57  46  50]
#   ...
#   [169 172 179]
#   [169 169 179]
#   [169 169 179]]
#
#  ...
#
#  [[ 47  37  36]
#   [ 44  36  34]
#   [ 38  33  30]
#   ...
#   [ 36  28  25]
#   [ 35  25  23]
#   [ 36  26  24]]
#
#  [[ 41  29  31]
#   [ 42  30  32]
#   [ 42  33  34]
#   ...
#   [ 36  28  25]
#   [ 36  25  21]
#   [ 37  26  22]]
#
#  [[ 48  33  36]
#   [ 46  34  36]
#   [ 47  37  38]
#   ...
#   [ 37  29  26]
#   [ 36  25  21]
#   [ 40  26  23]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/10
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/10
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 48.  36.  38.]
#   [ 50.  38.  40.]
#   [ 56.  46.  45.]
#   ...
#   [165. 164. 178.]
#   [164. 163. 181.]
#   [165. 164. 182.]]
#
#  [[ 52.  40.  42.]
#   [ 52.  40.  42.]
#   [ 56.  46.  47.]
#   ...
#   [164. 164. 176.]
#   [161. 160. 174.]
#   [161. 160. 176.]]
#
#  [[ 53.  41.  45.]
#   [ 53.  41.  45.]
#   [ 57.  46.  50.]
#   ...
#   [169. 172. 179.]
#   [169. 169. 179.]
#   [169. 169. 179.]]
#
#  ...
#
#  [[ 47.  37.  36.]
#   [ 44.  36.  34.]
#   [ 38.  33.  30.]
#   ...
#   [ 36.  28.  25.]
#   [ 35.  25.  23.]
#   [ 36.  26.  24.]]
#
#  [[ 41.  29.  31.]
#   [ 42.  30.  32.]
#   [ 42.  33.  34.]
#   ...
#   [ 36.  28.  25.]
#   [ 36.  25.  21.]
#   [ 37.  26.  22.]]
#
#  [[ 48.  33.  36.]
#   [ 46.  34.  36.]
#   [ 47.  37.  38.]
#   ...
#   [ 37.  29.  26.]
#   [ 36.  25.  21.]
#   [ 40.  26.  23.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/10
# Loading Image File with Keras... dataset/good/1/10
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 58  45  55]
#   [ 57  44  53]
#   [ 56  45  53]
#   ...
#   [171 179 168]
#   [171 178 170]
#   [170 177 169]]
#
#  [[ 54  41  51]
#   [ 52  39  48]
#   [ 57  44  51]
#   ...
#   [164 172 161]
#   [167 172 165]
#   [166 173 165]]
#
#  [[ 53  37  47]
#   [ 50  37  46]
#   [ 56  44  48]
#   ...
#   [168 174 164]
#   [171 174 167]
#   [168 173 166]]
#
#  ...
#
#  [[ 48  46  33]
#   [ 47  45  32]
#   [ 45  43  30]
#   ...
#   [ 32  33  28]
#   [ 31  30  26]
#   [ 37  33  30]]
#
#  [[ 50  47  32]
#   [ 47  45  30]
#   [ 45  43  28]
#   ...
#   [ 34  35  29]
#   [ 31  30  25]
#   [ 35  34  29]]
#
#  [[ 50  47  30]
#   [ 48  45  28]
#   [ 45  44  26]
#   ...
#   [ 33  34  26]
#   [ 36  35  30]
#   [ 32  31  26]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/11
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/11
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 58.  45.  55.]
#   [ 57.  44.  53.]
#   [ 56.  45.  53.]
#   ...
#   [171. 179. 168.]
#   [171. 178. 170.]
#   [170. 177. 169.]]
#
#  [[ 54.  41.  51.]
#   [ 52.  39.  48.]
#   [ 57.  44.  51.]
#   ...
#   [164. 172. 161.]
#   [167. 172. 165.]
#   [166. 173. 165.]]
#
#  [[ 53.  37.  47.]
#   [ 50.  37.  46.]
#   [ 56.  44.  48.]
#   ...
#   [168. 174. 164.]
#   [171. 174. 167.]
#   [168. 173. 166.]]
#
#  ...
#
#  [[ 48.  46.  33.]
#   [ 47.  45.  32.]
#   [ 45.  43.  30.]
#   ...
#   [ 32.  33.  28.]
#   [ 31.  30.  26.]
#   [ 37.  33.  30.]]
#
#  [[ 50.  47.  32.]
#   [ 47.  45.  30.]
#   [ 45.  43.  28.]
#   ...
#   [ 34.  35.  29.]
#   [ 31.  30.  25.]
#   [ 35.  34.  29.]]
#
#  [[ 50.  47.  30.]
#   [ 48.  45.  28.]
#   [ 45.  44.  26.]
#   ...
#   [ 33.  34.  26.]
#   [ 36.  35.  30.]
#   [ 32.  31.  26.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/11
# Loading Image File with Keras... dataset/good/1/11
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 53  44  39]
#   [ 53  44  39]
#   [ 56  47  40]
#   ...
#   [177 179 176]
#   [172 173 168]
#   [173 174 169]]
#
#  [[ 52  43  38]
#   [ 53  44  39]
#   [ 55  46  39]
#   ...
#   [166 168 165]
#   [167 169 166]
#   [169 171 168]]
#
#  [[ 54  45  40]
#   [ 55  46  41]
#   [ 54  45  38]
#   ...
#   [165 169 170]
#   [166 170 171]
#   [170 174 175]]
#
#  ...
#
#  [[ 43  38  35]
#   [ 43  38  35]
#   [ 45  36  39]
#   ...
#   [ 36  25  33]
#   [ 37  24  33]
#   [ 36  23  33]]
#
#  [[ 46  34  36]
#   [ 45  34  38]
#   [ 45  34  38]
#   ...
#   [ 35  26  31]
#   [ 35  24  32]
#   [ 35  24  32]]
#
#  [[ 47  32  37]
#   [ 44  32  36]
#   [ 44  31  38]
#   ...
#   [ 35  26  29]
#   [ 35  24  32]
#   [ 35  24  32]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/12
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/12
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 53.  44.  39.]
#   [ 53.  44.  39.]
#   [ 56.  47.  40.]
#   ...
#   [177. 179. 176.]
#   [172. 173. 168.]
#   [173. 174. 169.]]
#
#  [[ 52.  43.  38.]
#   [ 53.  44.  39.]
#   [ 55.  46.  39.]
#   ...
#   [166. 168. 165.]
#   [167. 169. 166.]
#   [169. 171. 168.]]
#
#  [[ 54.  45.  40.]
#   [ 55.  46.  41.]
#   [ 54.  45.  38.]
#   ...
#   [165. 169. 170.]
#   [166. 170. 171.]
#   [170. 174. 175.]]
#
#  ...
#
#  [[ 43.  38.  35.]
#   [ 43.  38.  35.]
#   [ 45.  36.  39.]
#   ...
#   [ 36.  25.  33.]
#   [ 37.  24.  33.]
#   [ 36.  23.  33.]]
#
#  [[ 46.  34.  36.]
#   [ 45.  34.  38.]
#   [ 45.  34.  38.]
#   ...
#   [ 35.  26.  31.]
#   [ 35.  24.  32.]
#   [ 35.  24.  32.]]
#
#  [[ 47.  32.  37.]
#   [ 44.  32.  36.]
#   [ 44.  31.  38.]
#   ...
#   [ 35.  26.  29.]
#   [ 35.  24.  32.]
#   [ 35.  24.  32.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/12
# Loading Image File with Keras... dataset/good/1/12
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 56  39  57]
#   [ 56  39  57]
#   [ 51  34  52]
#   ...
#   [174 176 175]
#   [170 172 169]
#   [172 174 171]]
#
#  [[ 55  38  54]
#   [ 51  37  52]
#   [ 54  37  53]
#   ...
#   [172 174 173]
#   [171 173 172]
#   [174 176 175]]
#
#  [[ 52  38  51]
#   [ 51  39  51]
#   [ 54  40  53]
#   ...
#   [170 174 175]
#   [172 173 175]
#   [172 173 175]]
#
#  ...
#
#  [[ 43  42  37]
#   [ 42  41  36]
#   [ 40  39  35]
#   ...
#   [ 32  26  28]
#   [ 33  29  30]
#   [ 33  32  30]]
#
#  [[ 42  44  30]
#   [ 42  44  30]
#   [ 41  43  30]
#   ...
#   [ 35  29  33]
#   [ 36  30  34]
#   [ 35  31  32]]
#
#  [[ 37  40  21]
#   [ 38  41  22]
#   [ 39  41  27]
#   ...
#   [ 39  29  37]
#   [ 36  30  34]
#   [ 33  27  31]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/13
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/13
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 56.  39.  57.]
#   [ 56.  39.  57.]
#   [ 51.  34.  52.]
#   ...
#   [174. 176. 175.]
#   [170. 172. 169.]
#   [172. 174. 171.]]
#
#  [[ 55.  38.  54.]
#   [ 51.  37.  52.]
#   [ 54.  37.  53.]
#   ...
#   [172. 174. 173.]
#   [171. 173. 172.]
#   [174. 176. 175.]]
#
#  [[ 52.  38.  51.]
#   [ 51.  39.  51.]
#   [ 54.  40.  53.]
#   ...
#   [170. 174. 175.]
#   [172. 173. 175.]
#   [172. 173. 175.]]
#
#  ...
#
#  [[ 43.  42.  37.]
#   [ 42.  41.  36.]
#   [ 40.  39.  35.]
#   ...
#   [ 32.  26.  28.]
#   [ 33.  29.  30.]
#   [ 33.  32.  30.]]
#
#  [[ 42.  44.  30.]
#   [ 42.  44.  30.]
#   [ 41.  43.  30.]
#   ...
#   [ 35.  29.  33.]
#   [ 36.  30.  34.]
#   [ 35.  31.  32.]]
#
#  [[ 37.  40.  21.]
#   [ 38.  41.  22.]
#   [ 39.  41.  27.]
#   ...
#   [ 39.  29.  37.]
#   [ 36.  30.  34.]
#   [ 33.  27.  31.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/13
# Loading Image File with Keras... dataset/good/1/13
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 52  44  42]
#   [ 50  42  40]
#   [ 61  51  52]
#   ...
#   [165 163 166]
#   [170 168 169]
#   [171 169 170]]
#
#  [[ 51  45  45]
#   [ 45  39  39]
#   [ 54  45  46]
#   ...
#   [165 165 167]
#   [166 164 167]
#   [162 162 164]]
#
#  [[ 50  46  47]
#   [ 49  45  46]
#   [ 59  53  55]
#   ...
#   [173 174 178]
#   [173 172 177]
#   [169 170 174]]
#
#  ...
#
#  [[ 38  39  33]
#   [ 41  42  36]
#   [ 37  36  32]
#   ...
#   [ 33  27  31]
#   [ 33  26  33]
#   [ 32  25  32]]
#
#  [[ 39  39  31]
#   [ 41  41  33]
#   [ 43  40  35]
#   ...
#   [ 32  27  33]
#   [ 33  28  35]
#   [ 32  27  34]]
#
#  [[ 44  44  36]
#   [ 40  40  32]
#   [ 46  43  38]
#   ...
#   [ 33  28  34]
#   [ 32  27  34]
#   [ 32  27  34]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/14
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/14
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 52.  44.  42.]
#   [ 50.  42.  40.]
#   [ 61.  51.  52.]
#   ...
#   [165. 163. 166.]
#   [170. 168. 169.]
#   [171. 169. 170.]]
#
#  [[ 51.  45.  45.]
#   [ 45.  39.  39.]
#   [ 54.  45.  46.]
#   ...
#   [165. 165. 167.]
#   [166. 164. 167.]
#   [162. 162. 164.]]
#
#  [[ 50.  46.  47.]
#   [ 49.  45.  46.]
#   [ 59.  53.  55.]
#   ...
#   [173. 174. 178.]
#   [173. 172. 177.]
#   [169. 170. 174.]]
#
#  ...
#
#  [[ 38.  39.  33.]
#   [ 41.  42.  36.]
#   [ 37.  36.  32.]
#   ...
#   [ 33.  27.  31.]
#   [ 33.  26.  33.]
#   [ 32.  25.  32.]]
#
#  [[ 39.  39.  31.]
#   [ 41.  41.  33.]
#   [ 43.  40.  35.]
#   ...
#   [ 32.  27.  33.]
#   [ 33.  28.  35.]
#   [ 32.  27.  34.]]
#
#  [[ 44.  44.  36.]
#   [ 40.  40.  32.]
#   [ 46.  43.  38.]
#   ...
#   [ 33.  28.  34.]
#   [ 32.  27.  34.]
#   [ 32.  27.  34.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/14
# Loading Image File with Keras... dataset/good/1/14
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 51  44  51]
#   [ 52  42  50]
#   [ 52  41  49]
#   ...
#   [175 170 177]
#   [169 163 165]
#   [167 161 161]]
#
#  [[ 45  39  43]
#   [ 47  38  43]
#   [ 48  37  43]
#   ...
#   [175 170 176]
#   [172 168 169]
#   [177 173 172]]
#
#  [[ 49  43  45]
#   [ 50  41  44]
#   [ 51  40  44]
#   ...
#   [177 175 176]
#   [173 172 170]
#   [171 170 166]]
#
#  ...
#
#  [[ 42  36  48]
#   [ 38  32  44]
#   [ 37  31  41]
#   ...
#   [ 35  24  28]
#   [ 34  25  26]
#   [ 37  28  29]]
#
#  [[ 40  34  48]
#   [ 38  32  44]
#   [ 39  31  42]
#   ...
#   [ 32  26  28]
#   [ 32  28  27]
#   [ 33  29  26]]
#
#  [[ 41  35  49]
#   [ 40  34  46]
#   [ 38  30  43]
#   ...
#   [ 32  28  27]
#   [ 32  28  27]
#   [ 30  29  25]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/15
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/15
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 51.  44.  51.]
#   [ 52.  42.  50.]
#   [ 52.  41.  49.]
#   ...
#   [175. 170. 177.]
#   [169. 163. 165.]
#   [167. 161. 161.]]
#
#  [[ 45.  39.  43.]
#   [ 47.  38.  43.]
#   [ 48.  37.  43.]
#   ...
#   [175. 170. 176.]
#   [172. 168. 169.]
#   [177. 173. 172.]]
#
#  [[ 49.  43.  45.]
#   [ 50.  41.  44.]
#   [ 51.  40.  44.]
#   ...
#   [177. 175. 176.]
#   [173. 172. 170.]
#   [171. 170. 166.]]
#
#  ...
#
#  [[ 42.  36.  48.]
#   [ 38.  32.  44.]
#   [ 37.  31.  41.]
#   ...
#   [ 35.  24.  28.]
#   [ 34.  25.  26.]
#   [ 37.  28.  29.]]
#
#  [[ 40.  34.  48.]
#   [ 38.  32.  44.]
#   [ 39.  31.  42.]
#   ...
#   [ 32.  26.  28.]
#   [ 32.  28.  27.]
#   [ 33.  29.  26.]]
#
#  [[ 41.  35.  49.]
#   [ 40.  34.  46.]
#   [ 38.  30.  43.]
#   ...
#   [ 32.  28.  27.]
#   [ 32.  28.  27.]
#   [ 30.  29.  25.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/15
# Loading Image File with Keras... dataset/good/1/15
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 47  38  41]
#   [ 52  43  46]
#   [ 46  40  42]
#   ...
#   [173 171 172]
#   [168 164 165]
#   [175 171 170]]
#
#  [[ 46  37  42]
#   [ 50  41  44]
#   [ 49  43  47]
#   ...
#   [173 171 174]
#   [166 164 167]
#   [170 168 169]]
#
#  [[ 53  43  51]
#   [ 49  40  45]
#   [ 50  43  50]
#   ...
#   [173 172 178]
#   [168 167 173]
#   [169 168 174]]
#
#  ...
#
#  [[ 48  39  44]
#   [ 45  36  39]
#   [ 48  39  42]
#   ...
#   [ 34  23  29]
#   [ 34  21  30]
#   [ 35  23  33]]
#
#  [[ 52  39  48]
#   [ 47  34  43]
#   [ 48  37  45]
#   ...
#   [ 33  23  32]
#   [ 35  23  35]
#   [ 36  25  39]]
#
#  [[ 47  31  42]
#   [ 44  28  39]
#   [ 43  30  39]
#   ...
#   [ 35  25  36]
#   [ 36  25  39]
#   [ 35  24  40]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/16
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/16
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 47.  38.  41.]
#   [ 52.  43.  46.]
#   [ 46.  40.  42.]
#   ...
#   [173. 171. 172.]
#   [168. 164. 165.]
#   [175. 171. 170.]]
#
#  [[ 46.  37.  42.]
#   [ 50.  41.  44.]
#   [ 49.  43.  47.]
#   ...
#   [173. 171. 174.]
#   [166. 164. 167.]
#   [170. 168. 169.]]
#
#  [[ 53.  43.  51.]
#   [ 49.  40.  45.]
#   [ 50.  43.  50.]
#   ...
#   [173. 172. 178.]
#   [168. 167. 173.]
#   [169. 168. 174.]]
#
#  ...
#
#  [[ 48.  39.  44.]
#   [ 45.  36.  39.]
#   [ 48.  39.  42.]
#   ...
#   [ 34.  23.  29.]
#   [ 34.  21.  30.]
#   [ 35.  23.  33.]]
#
#  [[ 52.  39.  48.]
#   [ 47.  34.  43.]
#   [ 48.  37.  45.]
#   ...
#   [ 33.  23.  32.]
#   [ 35.  23.  35.]
#   [ 36.  25.  39.]]
#
#  [[ 47.  31.  42.]
#   [ 44.  28.  39.]
#   [ 43.  30.  39.]
#   ...
#   [ 35.  25.  36.]
#   [ 36.  25.  39.]
#   [ 35.  24.  40.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/16
# Loading Image File with Keras... dataset/good/1/16
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 46  44  45]
#   [ 43  42  40]
#   [ 46  45  43]
#   ...
#   [164 166 165]
#   [165 166 171]
#   [164 164 172]]
#
#  [[ 51  46  50]
#   [ 49  45  46]
#   [ 51  47  46]
#   ...
#   [173 175 174]
#   [167 168 173]
#   [169 169 177]]
#
#  [[ 48  41  48]
#   [ 47  41  45]
#   [ 52  46  46]
#   ...
#   [165 169 170]
#   [169 173 176]
#   [168 171 176]]
#
#  ...
#
#  [[ 51  41  42]
#   [ 41  31  32]
#   [ 42  33  34]
#   ...
#   [ 32  30  33]
#   [ 31  29  32]
#   [ 30  30  32]]
#
#  [[ 50  38  40]
#   [ 44  34  35]
#   [ 46  38  36]
#   ...
#   [ 29  29  31]
#   [ 28  28  28]
#   [ 27  29  28]]
#
#  [[ 50  38  40]
#   [ 47  37  38]
#   [ 46  36  35]
#   ...
#   [ 30  30  32]
#   [ 31  33  32]
#   [ 29  31  30]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/17
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/17
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 46.  44.  45.]
#   [ 43.  42.  40.]
#   [ 46.  45.  43.]
#   ...
#   [164. 166. 165.]
#   [165. 166. 171.]
#   [164. 164. 172.]]
#
#  [[ 51.  46.  50.]
#   [ 49.  45.  46.]
#   [ 51.  47.  46.]
#   ...
#   [173. 175. 174.]
#   [167. 168. 173.]
#   [169. 169. 177.]]
#
#  [[ 48.  41.  48.]
#   [ 47.  41.  45.]
#   [ 52.  46.  46.]
#   ...
#   [165. 169. 170.]
#   [169. 173. 176.]
#   [168. 171. 176.]]
#
#  ...
#
#  [[ 51.  41.  42.]
#   [ 41.  31.  32.]
#   [ 42.  33.  34.]
#   ...
#   [ 32.  30.  33.]
#   [ 31.  29.  32.]
#   [ 30.  30.  32.]]
#
#  [[ 50.  38.  40.]
#   [ 44.  34.  35.]
#   [ 46.  38.  36.]
#   ...
#   [ 29.  29.  31.]
#   [ 28.  28.  28.]
#   [ 27.  29.  28.]]
#
#  [[ 50.  38.  40.]
#   [ 47.  37.  38.]
#   [ 46.  36.  35.]
#   ...
#   [ 30.  30.  32.]
#   [ 31.  33.  32.]
#   [ 29.  31.  30.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/17
# Loading Image File with Keras... dataset/good/1/17
# ...
#   ...
#   [168 176 165]
#   [169 176 169]
#   [171 178 171]]
#
#  [[ 73  72  80]
#   [ 75  75  83]
#   [ 70  69  77]
#   ...
#   [159 166 158]
#   [158 165 158]
#   [170 177 170]]
#
#  [[ 73  70  79]
#   [ 74  73  81]
#   [ 70  67  76]
#   ...
#   [165 175 167]
#   [170 179 174]
#   [165 174 169]]
#
#  ...
#
#  [[ 42  33  38]
#   [ 44  35  38]
#   [ 48  42  42]
#   ...
#   [ 31  26  32]
#   [ 32  27  33]
#   [ 32  27  34]]
#
#  [[ 52  42  41]
#   [ 48  40  38]
#   [ 43  38  35]
#   ...
#   [ 33  30  37]
#   [ 33  30  39]
#   [ 30  27  36]]
#
#  [[ 48  38  36]
#   [ 50  42  39]
#   [ 45  37  34]
#   ...
#   [ 36  33  40]
#   [ 34  31  42]
#   [ 29  26  37]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/139
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/139
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 69.  69.  77.]
#   [ 65.  65.  73.]
#   [ 69.  69.  79.]
#   ...
#   [168. 176. 165.]
#   [169. 176. 169.]
#   [171. 178. 171.]]
#
#  [[ 73.  72.  80.]
#   [ 75.  75.  83.]
#   [ 70.  69.  77.]
#   ...
#   [159. 166. 158.]
#   [158. 165. 158.]
#   [170. 177. 170.]]
#
#  [[ 73.  70.  79.]
#   [ 74.  73.  81.]
#   [ 70.  67.  76.]
#   ...
#   [165. 175. 167.]
#   [170. 179. 174.]
#   [165. 174. 169.]]
#
#  ...
#
#  [[ 42.  33.  38.]
#   [ 44.  35.  38.]
#   [ 48.  42.  42.]
#   ...
#   [ 31.  26.  32.]
#   [ 32.  27.  33.]
#   [ 32.  27.  34.]]
#
#  [[ 52.  42.  41.]
#   [ 48.  40.  38.]
#   [ 43.  38.  35.]
#   ...
#   [ 33.  30.  37.]
#   [ 33.  30.  39.]
#   [ 30.  27.  36.]]
#
#  [[ 48.  38.  36.]
#   [ 50.  42.  39.]
#   [ 45.  37.  34.]
#   ...
#   [ 36.  33.  40.]
#   [ 34.  31.  42.]
#   [ 29.  26.  37.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/139
# Loading Image File with Keras... dataset/good/1/139
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 64  79  76]
#   [ 58  73  70]
#   [ 63  73  72]
#   ...
#   [174 169 175]
#   [175 170 176]
#   [183 178 184]]
#
#  [[ 67  79  77]
#   [ 64  74  73]
#   [ 66  75  74]
#   ...
#   [171 169 174]
#   [174 172 177]
#   [182 180 183]]
#
#  [[ 73  78  81]
#   [ 74  79  82]
#   [ 74  78  81]
#   ...
#   [169 169 171]
#   [174 175 177]
#   [176 178 177]]
#
#  ...
#
#  [[ 44  41  36]
#   [ 40  39  35]
#   [ 39  38  34]
#   ...
#   [ 31  32  34]
#   [ 31  31  33]
#   [ 28  29  31]]
#
#  [[ 44  39  33]
#   [ 43  40  33]
#   [ 42  39  34]
#   ...
#   [ 26  30  29]
#   [ 28  29  31]
#   [ 28  32  33]]
#
#  [[ 46  42  33]
#   [ 45  41  32]
#   [ 41  38  33]
#   ...
#   [ 25  29  28]
#   [ 28  32  33]
#   [ 37  41  42]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/140
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/140
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 64.  79.  76.]
#   [ 58.  73.  70.]
#   [ 63.  73.  72.]
#   ...
#   [174. 169. 175.]
#   [175. 170. 176.]
#   [183. 178. 184.]]
#
#  [[ 67.  79.  77.]
#   [ 64.  74.  73.]
#   [ 66.  75.  74.]
#   ...
#   [171. 169. 174.]
#   [174. 172. 177.]
#   [182. 180. 183.]]
#
#  [[ 73.  78.  81.]
#   [ 74.  79.  82.]
#   [ 74.  78.  81.]
#   ...
#   [169. 169. 171.]
#   [174. 175. 177.]
#   [176. 178. 177.]]
#
#  ...
#
#  [[ 44.  41.  36.]
#   [ 40.  39.  35.]
#   [ 39.  38.  34.]
#   ...
#   [ 31.  32.  34.]
#   [ 31.  31.  33.]
#   [ 28.  29.  31.]]
#
#  [[ 44.  39.  33.]
#   [ 43.  40.  33.]
#   [ 42.  39.  34.]
#   ...
#   [ 26.  30.  29.]
#   [ 28.  29.  31.]
#   [ 28.  32.  33.]]
#
#  [[ 46.  42.  33.]
#   [ 45.  41.  32.]
#   [ 41.  38.  33.]
#   ...
#   [ 25.  29.  28.]
#   [ 28.  32.  33.]
#   [ 37.  41.  42.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/140
# Loading Image File with Keras... dataset/good/1/140
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 75  71  68]
#   [ 80  76  73]
#   [ 74  73  71]
#   ...
#   [166 171 165]
#   [167 172 165]
#   [171 176 169]]
#
#  [[ 77  73  72]
#   [ 77  73  72]
#   [ 84  80  81]
#   ...
#   [167 172 165]
#   [168 174 164]
#   [167 173 163]]
#
#  [[ 86  79  86]
#   [ 76  71  77]
#   [ 79  74  80]
#   ...
#   [169 177 164]
#   [170 176 162]
#   [165 171 157]]
#
#  ...
#
#  [[ 48  45  36]
#   [ 47  45  33]
#   [ 46  44  32]
#   ...
#   [ 31  31  29]
#   [ 31  31  29]
#   [ 33  33  31]]
#
#  [[ 46  46  34]
#   [ 44  45  31]
#   [ 42  43  27]
#   ...
#   [ 30  30  30]
#   [ 30  30  30]
#   [ 31  31  31]]
#
#  [[ 46  47  33]
#   [ 46  47  31]
#   [ 45  46  30]
#   ...
#   [ 30  30  32]
#   [ 29  29  29]
#   [ 30  30  30]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/141
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/141
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 75.  71.  68.]
#   [ 80.  76.  73.]
#   [ 74.  73.  71.]
#   ...
#   [166. 171. 165.]
#   [167. 172. 165.]
#   [171. 176. 169.]]
#
#  [[ 77.  73.  72.]
#   [ 77.  73.  72.]
#   [ 84.  80.  81.]
#   ...
#   [167. 172. 165.]
#   [168. 174. 164.]
#   [167. 173. 163.]]
#
#  [[ 86.  79.  86.]
#   [ 76.  71.  77.]
#   [ 79.  74.  80.]
#   ...
#   [169. 177. 164.]
#   [170. 176. 162.]
#   [165. 171. 157.]]
#
#  ...
#
#  [[ 48.  45.  36.]
#   [ 47.  45.  33.]
#   [ 46.  44.  32.]
#   ...
#   [ 31.  31.  29.]
#   [ 31.  31.  29.]
#   [ 33.  33.  31.]]
#
#  [[ 46.  46.  34.]
#   [ 44.  45.  31.]
#   [ 42.  43.  27.]
#   ...
#   [ 30.  30.  30.]
#   [ 30.  30.  30.]
#   [ 31.  31.  31.]]
#
#  [[ 46.  47.  33.]
#   [ 46.  47.  31.]
#   [ 45.  46.  30.]
#   ...
#   [ 30.  30.  32.]
#   [ 29.  29.  29.]
#   [ 30.  30.  30.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/141
# Loading Image File with Keras... dataset/good/1/141
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 75  74  82]
#   [ 70  69  74]
#   [ 76  76  76]
#   ...
#   [162 171 166]
#   [167 171 172]
#   [172 176 179]]
#
#  [[ 73  72  80]
#   [ 76  75  81]
#   [ 78  78  78]
#   ...
#   [165 174 171]
#   [162 167 170]
#   [166 171 175]]
#
#  [[ 74  73  81]
#   [ 71  70  76]
#   [ 75  75  75]
#   ...
#   [167 175 177]
#   [159 166 172]
#   [162 169 177]]
#
#  ...
#
#  [[ 40  45  38]
#   [ 38  44  34]
#   [ 37  40  31]
#   ...
#   [ 34  28  32]
#   [ 34  27  34]
#   [ 31  26  30]]
#
#  [[ 36  42  40]
#   [ 34  39  35]
#   [ 35  37  32]
#   ...
#   [ 34  27  34]
#   [ 32  25  33]
#   [ 32  25  32]]
#
#  [[ 39  45  45]
#   [ 36  42  40]
#   [ 37  39  36]
#   ...
#   [ 36  26  35]
#   [ 30  23  31]
#   [ 32  25  33]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/142
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/142
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 75.  74.  82.]
#   [ 70.  69.  74.]
#   [ 76.  76.  76.]
#   ...
#   [162. 171. 166.]
#   [167. 171. 172.]
#   [172. 176. 179.]]
#
#  [[ 73.  72.  80.]
#   [ 76.  75.  81.]
#   [ 78.  78.  78.]
#   ...
#   [165. 174. 171.]
#   [162. 167. 170.]
#   [166. 171. 175.]]
#
#  [[ 74.  73.  81.]
#   [ 71.  70.  76.]
#   [ 75.  75.  75.]
#   ...
#   [167. 175. 177.]
#   [159. 166. 172.]
#   [162. 169. 177.]]
#
#  ...
#
#  [[ 40.  45.  38.]
#   [ 38.  44.  34.]
#   [ 37.  40.  31.]
#   ...
#   [ 34.  28.  32.]
#   [ 34.  27.  34.]
#   [ 31.  26.  30.]]
#
#  [[ 36.  42.  40.]
#   [ 34.  39.  35.]
#   [ 35.  37.  32.]
#   ...
#   [ 34.  27.  34.]
#   [ 32.  25.  33.]
#   [ 32.  25.  32.]]
#
#  [[ 39.  45.  45.]
#   [ 36.  42.  40.]
#   [ 37.  39.  36.]
#   ...
#   [ 36.  26.  35.]
#   [ 30.  23.  31.]
#   [ 32.  25.  33.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/142
# Loading Image File with Keras... dataset/good/1/142
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 77  74  85]
#   [ 69  66  77]
#   [ 73  69  83]
#   ...
#   [166 167 169]
#   [168 167 172]
#   [165 164 169]]
#
#  [[ 71  68  79]
#   [ 74  71  82]
#   [ 74  70  84]
#   ...
#   [163 164 166]
#   [167 166 171]
#   [172 171 176]]
#
#  [[ 73  71  82]
#   [ 75  73  84]
#   [ 76  74  85]
#   ...
#   [167 168 170]
#   [170 169 174]
#   [174 173 178]]
#
#  ...
#
#  [[ 38  38  38]
#   [ 39  39  39]
#   [ 41  41  39]
#   ...
#   [ 30  24  36]
#   [ 32  26  38]
#   [ 35  29  41]]
#
#  [[ 37  38  33]
#   [ 41  42  37]
#   [ 43  44  38]
#   ...
#   [ 29  23  37]
#   [ 29  23  37]
#   [ 29  23  37]]
#
#  [[ 43  44  38]
#   [ 38  39  33]
#   [ 33  34  26]
#   ...
#   [ 31  25  39]
#   [ 32  25  41]
#   [ 29  22  38]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/143
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/143
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 77.  74.  85.]
#   [ 69.  66.  77.]
#   [ 73.  69.  83.]
#   ...
#   [166. 167. 169.]
#   [168. 167. 172.]
#   [165. 164. 169.]]
#
#  [[ 71.  68.  79.]
#   [ 74.  71.  82.]
#   [ 74.  70.  84.]
#   ...
#   [163. 164. 166.]
#   [167. 166. 171.]
#   [172. 171. 176.]]
#
#  [[ 73.  71.  82.]
#   [ 75.  73.  84.]
#   [ 76.  74.  85.]
#   ...
#   [167. 168. 170.]
#   [170. 169. 174.]
#   [174. 173. 178.]]
#
#  ...
#
#  [[ 38.  38.  38.]
#   [ 39.  39.  39.]
#   [ 41.  41.  39.]
#   ...
#   [ 30.  24.  36.]
#   [ 32.  26.  38.]
#   [ 35.  29.  41.]]
#
#  [[ 37.  38.  33.]
#   [ 41.  42.  37.]
#   [ 43.  44.  38.]
#   ...
#   [ 29.  23.  37.]
#   [ 29.  23.  37.]
#   [ 29.  23.  37.]]
#
#  [[ 43.  44.  38.]
#   [ 38.  39.  33.]
#   [ 33.  34.  26.]
#   ...
#   [ 31.  25.  39.]
#   [ 32.  25.  41.]
#   [ 29.  22.  38.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/143
# Loading Image File with Keras... dataset/good/1/143
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Image format:  JPEG
# Image mode:  RGB
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)
# [[[ 69  67  68]
#   [ 70  68  69]
#   [ 73  71  72]
#   ...
#   [169 175 161]
#   [174 177 168]
#   [179 182 173]]
#
#  [[ 68  66  69]
#   [ 70  68  71]
#   [ 75  73  76]
#   ...
#   [168 174 160]
#   [172 175 164]
#   [180 183 174]]
#
#  [[ 76  74  79]
#   [ 72  70  75]
#   [ 76  74  79]
#   ...
#   [163 171 156]
#   [171 177 165]
#   [168 174 162]]
#
#  ...
#
#  [[ 55  41  40]
#   [ 51  37  36]
#   [ 50  39  37]
#   ...
#   [ 31  28  37]
#   [ 31  28  37]
#   [ 31  28  37]]
#
#  [[ 53  38  35]
#   [ 48  34  31]
#   [ 50  36  35]
#   ...
#   [ 31  28  39]
#   [ 31  28  39]
#   [ 31  28  39]]
#
#  [[ 53  38  33]
#   [ 52  37  32]
#   [ 54  40  39]
#   ...
#   [ 30  27  38]
#   [ 31  28  39]
#   [ 32  29  40]]]
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB
# Saving as PNG (RGB)... dataset/good/1/144
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/1/144
# <class 'numpy.ndarray'> (544, 960)
# Image dtype:  uint8
# Image shape:  (544, 960, 3)
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>
# [[[ 69.  67.  68.]
#   [ 70.  68.  69.]
#   [ 73.  71.  72.]
#   ...
#   [169. 175. 161.]
#   [174. 177. 168.]
#   [179. 182. 173.]]
#
#  [[ 68.  66.  69.]
#   [ 70.  68.  71.]
#   [ 75.  73.  76.]
#   ...
#   [168. 174. 160.]
#   [172. 175. 164.]
#   [180. 183. 174.]]
#
#  [[ 76.  74.  79.]
#   [ 72.  70.  75.]
#   [ 76.  74.  79.]
#   ...
#   [163. 171. 156.]
#   [171. 177. 165.]
#   [168. 174. 162.]]
#
#  ...
#
#  [[ 55.  41.  40.]
#   [ 51.  37.  36.]
#   [ 50.  39.  37.]
#   ...
#   [ 31.  28.  37.]
#   [ 31.  28.  37.]
#   [ 31.  28.  37.]]
#
#  [[ 53.  38.  35.]
#   [ 48.  34.  31.]
#   [ 50.  36.  35.]
#   ...
#   [ 31.  28.  39.]
#   [ 31.  28.  39.]
#   [ 31.  28.  39.]]
#
#  [[ 53.  38.  33.]
#   [ 52.  37.  32.]
#   [ 54.  40.  39.]
#   ...
#   [ 30.  27.  38.]
#   [ 31.  28.  39.]
#   [ 32.  29.  40.]]]
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/144
# Loading Image File with Keras... dataset/good/1/144
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
# A.1. CONVERT an IMAGE to NP ARRAY
# - first import necessary libraries
from numpy import asarray
# - convert image format to numpy array
data = asarray(img)
# - inspect necessary information
print('data type: ', type(data))
print('data shape: ', data.shape)
# Out:
# data type:  <class 'numpy.ndarray'>
# data shape:  (544, 960, 3)

# %%
print(data)
# Out:
# [[[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0 14  0]
#   [ 0 12  0]
#   [ 0 11  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 1 15  0]
#   [ 1 13  1]
#   [ 0 12  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 1 15  0]
#   [ 1 13  1]
#   [ 0 12  0]]
#
#  ...
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]
#
#  [[ 3  1  4]
#   [ 2  0  3]
#   [ 1  0  2]
#   ...
#   [ 0  0  0]
#   [ 0  0  0]
#   [ 0  0  0]]]

# %%
# A.2. CONVERT NP ARRAY back to IMAGE format
# - convert numpy array to image format
img_fromnparray = Image.fromarray(data)
img_fromnparray.show()
# - inspect necessary information
print('Image size: ', img_fromnparray.size)
print('Image format: ', img_fromnparray.format)
print('Image mode: ', img_fromnparray.mode)
# Out:
# Image size:  (960, 544)
# Image format:  None
# Image mode:  RGB

# %%
# A.3. SAVE the IMAGE to ANOTHER FORMAT, e.g. PNG (source was JPG before)
#  - 1st reopen image, and save is as PNG
data = asarray(Image.open(ImageFile))
print("Saving as PNG (RGB)...", FilePath + str(FileName))
print(type(data), data.shape)
img_png = Image.fromarray(data).save(FilePath + str(FileName) + '_pil-rgb' + '.png')
#  - 2nd reopen image and convert it to grey, and save is as PNG
data = asarray(Image.open(ImageFile).convert('L'))
print("Saving as PNG (Grey)...", FilePath + str(FileName))
print(type(data), data.shape)
img_png = Image.fromarray(data).save(FilePath + str(FileName) + '_pil-grey' + '.png')
# Out:
# Saving as PNG (RGB)... dataset/good/processed 10
# <class 'numpy.ndarray'> (544, 960, 3)
# Saving as PNG (Grey)... dataset/good/processed 10
# <class 'numpy.ndarray'> (544, 960)

# %%
# B. IMAGE MANIPULATION with Matplotlib
# - first import necessary libraries
from matplotlib import image, pyplot
img = image.imread(ImageFile)
# - inspect necessary information
print('Image dtype: ', img.dtype)
print('Image shape: ', img.shape)
# - then show the image
pyplot.imshow(img)
# pyplot.show()
# Out:
# Image dtype:  uint8
# Image shape:  (544, 960, 3)

# %%
# A.4 Continuing IMAGE MANIPULATION with PIL
#     Rotate, Crop, Contrast & Brightness
#  - Image rotation with PIL
Rotation_Degree = 30
im = Image.open(ImageFile)
im.rotate(Rotation_Degree).show()
#  - Image crop with PIL
#    Looking at the pixel locations in above image, we can define the coordinate (box) to crop
box = (350, 100, 500, 200) #left, upper, right, lower
im.crop(box).show()

# %%
#  - Image Enhancements with PIL: Contrast
from PIL import ImageEnhance
im = Image.open(ImageFile)
enh = ImageEnhance.Contrast(im)
enh.enhance(1.75).show("75% more contrast")
#  - Image Enhancements with PIL: Brightness
enh = ImageEnhance.Brightness(im)
enh.enhance(1.5).show("50% more brightness")

# %%
# C. IMAGE MANIPULATION with Keras (built on top of Tensorflow)
# - first import necessary libraries
from tensorflow.keras.utils import load_img
import warnings
# - load and view the image
img = load_img(ImageFile)
print('Image type:', type(img), ', image format:', img.format, ', image mode:', img.mode, ', image size:', img.size)
img.show()
# Out:
# Image type: <class 'PIL.JpegImagePlugin.JpegImageFile'> , image format: JPEG , image mode: RGB , image size: (960, 544)

# %%
from tensorflow.keras.utils import img_to_array, array_to_img
print('Original type of image:', type(img))
# - convert the image to numpy array
img_nparray = img_to_array(img)
print('Numpy array info:', type(img_nparray))
print('type:', type(img_nparray.dtype))
print('shape:', type(img_nparray.shape))
# Out:
# Original type of image: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Numpy array info: <class 'numpy.ndarray'>
# type: <class 'numpy.dtype[float32]'>
# shape: <class 'tuple'>

# %%
print(img_nparray)
# Out:
# [[[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0. 14.  0.]
#   [ 0. 12.  0.]
#   [ 0. 11.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 1. 15.  0.]
#   [ 1. 13.  1.]
#   [ 0. 12.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 1. 15.  0.]
#   [ 1. 13.  1.]
#   [ 0. 12.  0.]]
#
#  ...
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]
#
#  [[ 3.  1.  4.]
#   [ 2.  0.  3.]
#   [ 1.  0.  2.]
#   ...
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]
#   [ 0.  0.  0.]]]

# %%
img_pil = array_to_img(img_nparray)
print("Converted (back) type of the image:", type(img_pil))
# - saving an image with keras
from tensorflow.keras.utils import load_img, save_img
ImageFile = FilePath + str(FileName) + '_keras' + '.png'
print("Saving Image File with Keras...", FilePath + str(FileName))
save_img(ImageFile, img_nparray)
# - loading an image with keras
print("Loading Image File with Keras...", FilePath + str(FileName))
img = load_img(ImageFile)
print('Image type:', type(img), ', image format:', img.format, ', image mode:', img.mode, ', image size:', img.size)
img.show()
# Out:
# Converted (back) type of the image: <class 'PIL.Image.Image'>
# Saving Image File with Keras... dataset/good/1/0
# Loading Image File with Keras... dataset/good/1/0
# Image type: <class 'PIL.PngImagePlugin.PngImageFile'> , image format: PNG , image mode: RGB , image size: (960, 544)

# %%
# *********************************
# D. IMAGE MANIPULATION with OpenCV
# *********************************
# - first import necessary libraries
# import cv2
# - set ImageFile to our original image, then read the image
ImageFile = FilePath + str(FileName) + FileExt
im = cv2.imread(ImageFile)
#cv2.imshow("my image", im)
# - save the file as PNG before conversion (internally it's in BGR order)
cv2.imwrite(FilePath + str(FileName) + '_opencvRGB' + '.png', im)
print(type(img))
# - convert to GRAY color space
img = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# - save the file as PNG after conversion
cv2.imwrite(FilePath + str(FileName) + '_opencvGREY' + '.png', img)
# - convert to HSV color space (typical for object tracking)
img = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
# - save the file as PNG after conversion
cv2.imwrite(FilePath + str(FileName) + '_opencvHSV' + '.png', img)
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# True

# %%
# - apply 50% blur
#   alternatively we can use cv2.imshow() to display the image instead of writing it to a file
#   e.g.:
#     cv2.imshow("OpenCV: apply 50% blur", img)
#     cv2.waitKey(0)
img = cv2.medianBlur(im, 5)
cv2.imwrite(FilePath + str(FileName) + '_opencvBLUR' + '.png', img)
# - apply Edge Detection
img = cv2.Canny(im, 100, 200)
cv2.imwrite(FilePath + str(FileName) + '_opencvEdgeDetect' + '.png', img)
# Out:
# True
